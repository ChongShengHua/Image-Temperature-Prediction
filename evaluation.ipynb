# %%
import numpy as np
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Overall train loss

# %%
model1_tl = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/model1_train_loss_8.csv')
model2_tl = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/model2_train_loss_100.csv')
model3_tl = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/model3_train_loss_8.csv')
model4_tl = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/model4_train_loss_100.csv')

# %%
model1_tl.sort_values('train_losses', ascending = True).head(1)
# Out:
#    epoch  train_losses
# 5    6.0      3.297877

# %%
model2_tl.sort_values('train_loss', ascending = True).head(1)
# Out:
#    epoch  train_loss
# 3      4    9.916624

# %%
model3_tl.sort_values('train_losses', ascending = True).head(1)
# Out:
#    epoch  train_losses
# 7    8.0      2.430375

# %%
model4_tl.sort_values('train_loss', ascending = True).head(1)
# Out:
#     epoch  train_loss
# 12   13.0    8.862251

# %% [markdown]
# # Overall RMSE

# %%
model1 = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/tested_result_model1_8.csv')
model3 = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/tested_result_model3_8.csv')

model2 = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/tested_result_model2_99.csv')
model4 = pd.read_csv('/content/drive/My Drive/TDS3651 Visual Information Processing/project/used code/tested_result_model4_99.csv')

# %%
model1.sort_values('rmse', ascending = True).head(1)
# Out:
#     model  epoch      rmse
# 7  model1      8  7.938904

# %%
model2.sort_values('rmse', ascending = True).head(1)
# Out:
#      model  epoch       rmse
# 48  model2     49  11.691613

# %%
model3.sort_values('rmse', ascending = True).head(1)
# Out:
#     model  epoch     rmse
# 7  model3      8  6.02161

# %%
model4.sort_values('rmse', ascending = True).head(1)
# Out:
#      model  epoch       rmse
# 12  model4      2  16.794318
